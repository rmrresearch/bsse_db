# %%
from bsse_calculator.plotting_helpers import prepare_bsse_data, plot_energy_types_by_distance

bsse_data_nwchem_kcal = prepare_bsse_data("BSSE_by_Ammonia_Ammonia_distance_nwchem.csv")
plot_energy_types_by_distance(bsse_data_nwchem_kcal, monomer="Ammonia", fit_spline=True)
